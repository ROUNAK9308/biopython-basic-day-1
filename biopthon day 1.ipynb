# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # New Section

# %%
print("hello world! My Bioinformatics Journey Starts Today!")
# Out:
# hello world! My Bioinformatics Journey Starts Today!
